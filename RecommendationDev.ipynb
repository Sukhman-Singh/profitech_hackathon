# %%
import pandas as pd

# %%
df = pd.read_csv('stock.csv')
df.head()
# Out:
#    No. Ticker Perf Week Perf Month Perf Quart Perf Half Perf Year Perf YTD  \
# 0    1   VTRS     1.08%     -1.54%      5.79%   -17.19%   -13.84%  -24.92%
# 1    2   HBAN     1.88%     -1.33%     -8.09%     6.47%    51.24%   11.48%
# 2    3   PBCT     2.88%     -8.40%    -13.40%    14.93%    39.68%   21.42%
# 3    4    HST     0.95%     -6.79%    -12.28%    17.56%    46.96%    8.89%
# 4    5    APA     2.97%    -13.31%     -6.25%    31.30%    17.11%   32.14%
#
#   Volatility W Volatility M Recom Avg Volume  Rel Volume  Price  Change  \
# 0        2.79%        2.47%  2.40      7.92M        0.86  14.07  -1.54%
# 1        2.79%        3.02%  2.20     17.15M        0.80  14.08  -1.95%
# 2        2.92%        2.97%  3.00      3.67M        5.02  15.70  -1.07%
# 3        2.90%        3.29%  2.70      8.04M        0.56  15.93  -2.15%
# 4        3.37%        4.24%  2.30      7.05M        0.85  18.75  -1.73%
#
#        Volume
# 0   6,839,429
# 1  13,659,505
# 2  18,423,274
# 3   4,531,286
# ...
